# %%
import os

# %%
a=os.getcwd().split("/")
foldername=a[-1]

# %%
template = [
    "src",
    "/src/logger.py",
    "/src/exception.py",
    "/src/config",
    "/src/components",
    "/src/pipeline"
                    
]
os.path.exists(template[1])
# Out:
# False

# %% [markdown]
# faq-bot/
# ├── src/
# │   ├── logger.py              # sab kuch log karega (kya ho raha hai, kab, kaha)
# │   ├── exception.py           # custom error handling (batayega exact file+line pe error)
# │   ├── config.py              # saari settings ek jagah (env vars, constants)
# │   ├── components/
# │   │   ├── data_ingestion.py       # sirf URL se data load karna
# │   │   ├── data_transformation.py  # sirf chunking
# │   │   ├── vector_store.py         # sirf embeddings + FAISS
# │   │   └── llm.py                  # sirf LLM + prompt setup
# │   └── pipeline/
# │       └── rag_pipeline.py    # sabko jodkar ek flow banana
# ├── app.py                     # sirf UI — koi business logic nahi
# ├── logs/                      # auto-generate hongi runtime pe
# ├── requirements.txt
# ├── .env.example
# └── README.md
